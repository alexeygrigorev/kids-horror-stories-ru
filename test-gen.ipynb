# %%
from openai import OpenAI

# %%
import process_stories

# %%
base64_image = process_stories.download_image_from_s3_to_base64(
    'kids-horror-stories-ru-images',
    'done/PXL_20250702_182800087.jpg'
)

# %%
story = process_stories.create_story(base64_image)

# %%
print(story.story)
# Out:
# На старом столе в углу комнаты стояли две картонные коробки. Одна из них была полна красками и кистями, а вторая — настоящим лесом из картона. Студентка Аня сделала его для школьного проекта. Деревья были вырезаны так искусно, что по ним легко было забыть, что перед тобой не настоящая природа.
#
# В тот вечер Аня осталась одна дома. Тишина давила, и она решила отвлечься от учёбы, разглядывая картонный шедевр. Вдруг она заметила нечто странное: одно из деревьев поменяло своё положение. "Наверное, просто игрушка сдвинулась," – подумала она и решила проверить.
#
# Подойдя ближе, Аня заметила, что одно из бумажных деревьев действительно выглядело иначе. Его силуэт стал вытянутым, а коробка казалась глубже, чем раньше. Девушка осторожно протянула руку, чтобы проверить. В тот же момент она почувствовала, как её пальцы прошли сквозь бумагу, словно её больше и не было.
#
# ...

# %%
story.slug
# Out:
# 'cardboard-forest'

# %%
story.title
# Out:
# 'Лес из картона'

# %%
story.story = process_stories.edit_story(story.story)

# %%
print(story.story)
# Out:
# На старом столе в углу комнаты стояли две картонные коробки. Одна была полна красок и кистей, а во второй скрывался целый картонный лес. Студентка Аня сделала его для учебного проекта. Деревья были вырезаны так искусно, что легко было забыть, что перед тобой — не настоящая природа.
#
# В тот вечер Аня осталась дома одна. Тишина давила, и она решила отвлечься от учёбы, разглядывая свой шедевр. Вдруг она заметила нечто странное: одно из деревьев поменяло положение. «Наверное, фигура сдвинулась», — подумала она и решила проверить.
#
# Подойдя ближе, Аня увидела, что одно из картонных деревьев действительно выглядело иначе. Его силуэт вытянулся, а коробка казалась глубже, чем раньше. Девушка осторожно протянула руку. В тот же момент она почувствовала, как её пальцы прошли сквозь картон, словно его больше и не было.
#
# ...
